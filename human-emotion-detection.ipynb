# %% [markdown]
# # 📖 Introduction

# %% [markdown]
# The goal of this project is to develop a deep learning model that can accurately classify facial expressions into one of seven categories: Angry, Disgust, Fear, Happy, Sad, Surprise, and Neutral. We will use convolutional neural networks (CNNs) to train our model, as they have been shown to be effective in image classification tasks. Our approach involves training a CNN model from scratch on the FER-2013 dataset
#
# ![emotions.png](attachment:02a21be9-12eb-4595-a450-8414036bac30.png)

# %% [markdown]
# # 💾 Data

# %% [markdown]
# The FER-2013 dataset consists of 48x48 pixel grayscale images of faces that have been automatically registered to be centred and occupy a similar amount of space in each image. The dataset contains 24,400 images, with 22,968 examples in the training set and 1,432 examples in the public test set.

# %% [markdown]
# # 🛠 Preprocessing

# %% [markdown]
# In this section, we will be using both data generators and data augmentation to train a deep learning model for human emotion detection using the FER-2013 dataset. Due to the size and complexity of the dataset, it would be impractical to load all of the images into memory at once. Therefore, we will be using data generators to generate batches of images on-the-fly during training, which will allow us to efficiently train our model on the entire dataset.
#
# In addition, we will be applying various data augmentation techniques to the training images, such as rotation, shifting, and flipping. This will help to increase the size and diversity of our training set, which can improve the performance of our deep learning model. By introducing variability into the training process, data augmentation can also help to prevent overfitting, which occurs when the model becomes too closely tailored to the training set and performs poorly on new, unseen data.

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
train_dir = "../input/fer2013/train" # Directory containing the training data
test_dir = "../input/fer2013/test"  # Directory containing the validation data

# %%
train_datagen = ImageDataGenerator(
    width_shift_range = 0.1,        # Randomly shift the width of images by up to 10%
    height_shift_range = 0.1,       # Randomly shift the height of images by up to 10%
    horizontal_flip = True,         # Flip images horizontally at random
    rescale = 1./255,               # Rescale pixel values to be between 0 and 1
    validation_split = 0.2          # Set aside 20% of the data for validation
)

validation_datagen = ImageDataGenerator(
    rescale = 1./255,               # Rescale pixel values to be between 0 and 1
    validation_split = 0.2          # Set aside 20% of the data for validation
)

# %%
train_generator = train_datagen.flow_from_directory(
    directory = train_dir,           # Directory containing the training data
    target_size = (48, 48),          # Resizes all images to 48x48 pixels
    batch_size = 64,                 # Number of images per batch
    color_mode = "grayscale",        # Converts the images to grayscale
    class_mode = "categorical",      # Classifies the images into 7 categories
    subset = "training"              # Uses the training subset of the data
)

validation_generator = validation_datagen.flow_from_directory(
    directory = test_dir,            # Directory containing the validation data
    target_size = (48, 48),          # Resizes all images to 48x48 pixels
    batch_size = 64,                 # Number of images per batch
    color_mode = "grayscale",        # Converts the images to grayscale
    class_mode = "categorical",      # Classifies the images into 7 categories
    subset = "validation"            # Uses the validation subset of the data
)
# Out:
# Found 22968 images belonging to 7 classes.
# Found 1432 images belonging to 7 classes.

# %% [markdown]
# # Modeling

# %% [markdown]
# ## CNN Model

# %% [markdown]
# To develop the CNN architecture, we will begin by defining the input layer and the number of filters in the first convolutional layer. Then, we will add additional convolutional layers with increasing numbers of filters, followed by max-pooling layers to reduce the spatial dimensions of the feature maps. After the convolutional layers, we will add fully connected layers with ReLU activation to classify the emotions.
#
# We will experiment with different numbers of convolutional layers, filter sizes, and fully connected layers to optimize the model performance. Additionally, we will use techniques such as dropout and batch normalization to prevent overfitting and improve the generalization capability of the model.

# %%
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.models import Sequential
import tensorflow as tf 

# Define the model architecture
model = Sequential()

# Add a convolutional layer with 32 filters, 3x3 kernel size, and relu activation function
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(48,48,1)))
# Add a batch normalization layer
model.add(BatchNormalization())
# Add a second convolutional layer with 64 filters, 3x3 kernel size, and relu activation function
model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
# Add a second batch normalization layer
model.add(BatchNormalization())
# Add a max pooling layer with 2x2 pool size
model.add(MaxPooling2D(pool_size=(2, 2)))
# Add a dropout layer with 0.25 dropout rate
model.add(Dropout(0.25))

# Add a third convolutional layer with 128 filters, 3x3 kernel size, and relu activation function
model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# Add a third batch normalization layer
model.add(BatchNormalization())
# Add a fourth convolutional layer with 128 filters, 3x3 kernel size, and relu activation function
model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# Add a fourth batch normalization layer
model.add(BatchNormalization())
# Add a max pooling layer with 2x2 pool size
model.add(MaxPooling2D(pool_size=(2, 2)))
# Add a dropout layer with 0.25 dropout rate
model.add(Dropout(0.25))

# Add a fifth convolutional layer with 256 filters, 3x3 kernel size, and relu activation function
model.add(Conv2D(256, kernel_size=(3, 3), activation='relu'))
# Add a fifth batch normalization layer
model.add(BatchNormalization())
# Add a sixth convolutional layer with 256 filters, 3x3 kernel size, and relu activation function
model.add(Conv2D(256, kernel_size=(3, 3), activation='relu'))
# Add a sixth batch normalization layer
model.add(BatchNormalization())
# Add a max pooling layer with 2x2 pool size
model.add(MaxPooling2D(pool_size=(2, 2)))
# Add a dropout layer with 0.25 dropout rate
model.add(Dropout(0.25))

# Flatten the output of the convolutional layers
model.add(Flatten())
# Add a dense layer with 256 neurons and relu activation function
model.add(Dense(256, activation='relu'))
# Add a seventh batch normalization layer
model.add(BatchNormalization())
# Add a dropout layer with 0.5 dropout rate
model.add(Dropout(0.5))
# Add a dense layer with 7 neurons (one for each class) and softmax activation function
model.add(Dense(7, activation='softmax'))

# Compile the model with categorical cross-entropy loss, adam optimizer, and accuracy metric
model.compile(loss="categorical_crossentropy", optimizer= tf.keras.optimizers.Adam(lr=0.0001), metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import ModelCheckpoint

# Define the callback
checkpoint_callback = ModelCheckpoint(
    filepath='model_weights.h5',
    monitor='val_accuracy',
    save_best_only=True,
    save_weights_only=True,
    mode='max',
    verbose=1
)

# Train the model with the callback
history = model.fit(
    train_generator,
    steps_per_epoch=len(train_generator),
    epochs=50,
    validation_data=validation_generator,
    validation_steps=len(validation_generator),
    callbacks=[checkpoint_callback]
)
# Out:
# Epoch 1/50
# 359/359 [==============================] - ETA: 0s - loss: 2.2071 - accuracy: 0.2464
# Epoch 1: val_accuracy improved from -inf to 0.23743, saving model to model_weights.h5
# 359/359 [==============================] - 388s 1s/step - loss: 2.2071 - accuracy: 0.2464 - val_loss: 1.8405 - val_accuracy: 0.2374
# Epoch 2/50
# 359/359 [==============================] - ETA: 0s - loss: 1.6773 - accuracy: 0.3708
# Epoch 2: val_accuracy improved from 0.23743 to 0.46299, saving model to model_weights.h5
# 359/359 [==============================] - 384s 1s/step - loss: 1.6773 - accuracy: 0.3708 - val_loss: 1.4971 - val_accuracy: 0.4630
# Epoch 3/50
# 359/359 [==============================] - ETA: 0s - loss: 1.4668 - accuracy: 0.4459
# Epoch 3: val_accuracy improved from 0.46299 to 0.49372, saving model to model_weights.h5
# 359/359 [==============================] - 385s 1s/step - loss: 1.4668 - accuracy: 0.4459 - val_loss: 1.3674 - val_accuracy: 0.4937
# Epoch 4/50
# 359/359 [==============================] - ETA: 0s - loss: 1.3465 - accuracy: 0.4900
# Epoch 4: val_accuracy improved from 0.49372 to 0.53701, saving model to model_weights.h5
# 359/359 [==============================] - 400s 1s/step - loss: 1.3465 - accuracy: 0.4900 - val_loss: 1.2237 - val_accuracy: 0.5370
# Epoch 5/50
# 359/359 [==============================] - ETA: 0s - loss: 1.2724 - accuracy: 0.5197
# Epoch 5: val_accuracy improved from 0.53701 to 0.54958, saving model to model_weights.h5
# 359/359 [==============================] - 387s 1s/step - loss: 1.2724 - accuracy: 0.5197 - val_loss: 1.2038 - val_accuracy: 0.5496
# Epoch 6/50
# 359/359 [==============================] - ETA: 0s - loss: 1.2322 - accuracy: 0.5339
# Epoch 6: val_accuracy did not improve from 0.54958
# 359/359 [==============================] - 390s 1s/step - loss: 1.2322 - accuracy: 0.5339 - val_loss: 1.1891 - val_accuracy: 0.5468
# Epoch 7/50
# 359/359 [==============================] - ETA: 0s - loss: 1.2030 - accuracy: 0.5431
# Epoch 7: val_accuracy improved from 0.54958 to 0.55447, saving model to model_weights.h5
# 359/359 [==============================] - 391s 1s/step - loss: 1.2030 - accuracy: 0.5431 - val_loss: 1.1623 - val_accuracy: 0.5545
# Epoch 8/50
# 359/359 [==============================] - ETA: 0s - loss: 1.1728 - accuracy: 0.5583
# Epoch 8: val_accuracy did not improve from 0.55447
# 359/359 [==============================] - 389s 1s/step - loss: 1.1728 - accuracy: 0.5583 - val_loss: 1.1844 - val_accuracy: 0.5503
# Epoch 9/50
# 359/359 [==============================] - ETA: 0s - loss: 1.1505 - accuracy: 0.5674
# Epoch 9: val_accuracy did not improve from 0.55447
# 359/359 [==============================] - 393s 1s/step - loss: 1.1505 - accuracy: 0.5674 - val_loss: 1.2205 - val_accuracy: 0.5279
# Epoch 10/50
# 359/359 [==============================] - ETA: 0s - loss: 1.1333 - accuracy: 0.5742
# Epoch 10: val_accuracy improved from 0.55447 to 0.58380, saving model to model_weights.h5
# 359/359 [==============================] - 389s 1s/step - loss: 1.1333 - accuracy: 0.5742 - val_loss: 1.0850 - val_accuracy: 0.5838
# Epoch 11/50
# 359/359 [==============================] - ETA: 0s - loss: 1.1030 - accuracy: 0.5852
# Epoch 11: val_accuracy did not improve from 0.58380
# 359/359 [==============================] - 383s 1s/step - loss: 1.1030 - accuracy: 0.5852 - val_loss: 1.0888 - val_accuracy: 0.5824
# Epoch 12/50
# 359/359 [==============================] - ETA: 0s - loss: 1.0929 - accuracy: 0.5899
# Epoch 12: val_accuracy did not improve from 0.58380
# 359/359 [==============================] - 391s 1s/step - loss: 1.0929 - accuracy: 0.5899 - val_loss: 1.1277 - val_accuracy: 0.5663
# Epoch 13/50
# 359/359 [==============================] - ETA: 0s - loss: 1.0722 - accuracy: 0.5982
# Epoch 13: val_accuracy improved from 0.58380 to 0.61313, saving model to model_weights.h5
# 359/359 [==============================] - 391s 1s/step - loss: 1.0722 - accuracy: 0.5982 - val_loss: 1.0237 - val_accuracy: 0.6131
# Epoch 14/50
# 359/359 [==============================] - ETA: 0s - loss: 1.0533 - accuracy: 0.6069
# Epoch 14: val_accuracy did not improve from 0.61313
# 359/359 [==============================] - 386s 1s/step - loss: 1.0533 - accuracy: 0.6069 - val_loss: 1.0530 - val_accuracy: 0.6103
# Epoch 15/50
# 359/359 [==============================] - ETA: 0s - loss: 1.0455 - accuracy: 0.6094
# Epoch 15: val_accuracy improved from 0.61313 to 0.63478, saving model to model_weights.h5
# 359/359 [==============================] - 396s 1s/step - loss: 1.0455 - accuracy: 0.6094 - val_loss: 0.9969 - val_accuracy: 0.6348
# Epoch 16/50
# 359/359 [==============================] - ETA: 0s - loss: 1.0281 - accuracy: 0.6143
# Epoch 16: val_accuracy did not improve from 0.63478
# 359/359 [==============================] - 387s 1s/step - loss: 1.0281 - accuracy: 0.6143 - val_loss: 1.0165 - val_accuracy: 0.6131
# Epoch 17/50
# 359/359 [==============================] - ETA: 0s - loss: 1.0138 - accuracy: 0.6220
# Epoch 17: val_accuracy did not improve from 0.63478
# 359/359 [==============================] - 388s 1s/step - loss: 1.0138 - accuracy: 0.6220 - val_loss: 1.2630 - val_accuracy: 0.5405
# Epoch 18/50
# 359/359 [==============================] - ETA: 0s - loss: 1.0063 - accuracy: 0.6268
# Epoch 18: val_accuracy improved from 0.63478 to 0.64385, saving model to model_weights.h5
# 359/359 [==============================] - 380s 1s/step - loss: 1.0063 - accuracy: 0.6268 - val_loss: 0.9749 - val_accuracy: 0.6439
# Epoch 19/50
# 359/359 [==============================] - ETA: 0s - loss: 0.9879 - accuracy: 0.6267
# Epoch 19: val_accuracy did not improve from 0.64385
# 359/359 [==============================] - 380s 1s/step - loss: 0.9879 - accuracy: 0.6267 - val_loss: 0.9898 - val_accuracy: 0.6341
# Epoch 20/50
# 359/359 [==============================] - ETA: 0s - loss: 0.9760 - accuracy: 0.6330
# Epoch 20: val_accuracy did not improve from 0.64385
# 359/359 [==============================] - 380s 1s/step - loss: 0.9760 - accuracy: 0.6330 - val_loss: 1.0662 - val_accuracy: 0.6034
# Epoch 21/50
# 359/359 [==============================] - ETA: 0s - loss: 0.9615 - accuracy: 0.6394
# Epoch 21: val_accuracy did not improve from 0.64385
# 359/359 [==============================] - 388s 1s/step - loss: 0.9615 - accuracy: 0.6394 - val_loss: 0.9839 - val_accuracy: 0.6299
# Epoch 22/50
# 359/359 [==============================] - ETA: 0s - loss: 0.9534 - accuracy: 0.6456
# Epoch 22: val_accuracy did not improve from 0.64385
# 359/359 [==============================] - 386s 1s/step - loss: 0.9534 - accuracy: 0.6456 - val_loss: 0.9855 - val_accuracy: 0.6334
# Epoch 23/50
# 359/359 [==============================] - ETA: 0s - loss: 0.9429 - accuracy: 0.6470
# Epoch 23: val_accuracy did not improve from 0.64385
# 359/359 [==============================] - 378s 1s/step - loss: 0.9429 - accuracy: 0.6470 - val_loss: 0.9843 - val_accuracy: 0.6264
# Epoch 24/50
# 359/359 [==============================] - ETA: 0s - loss: 0.9361 - accuracy: 0.6499
# Epoch 24: val_accuracy did not improve from 0.64385
# 359/359 [==============================] - 387s 1s/step - loss: 0.9361 - accuracy: 0.6499 - val_loss: 0.9749 - val_accuracy: 0.6369
# Epoch 25/50
# 359/359 [==============================] - ETA: 0s - loss: 0.9213 - accuracy: 0.6541
# Epoch 25: val_accuracy did not improve from 0.64385
# 359/359 [==============================] - 383s 1s/step - loss: 0.9213 - accuracy: 0.6541 - val_loss: 0.9746 - val_accuracy: 0.6278
# Epoch 26/50
# 359/359 [==============================] - ETA: 0s - loss: 0.9091 - accuracy: 0.6623
# Epoch 26: val_accuracy improved from 0.64385 to 0.64944, saving model to model_weights.h5
# 359/359 [==============================] - 390s 1s/step - loss: 0.9091 - accuracy: 0.6623 - val_loss: 0.9411 - val_accuracy: 0.6494
# Epoch 27/50
# 359/359 [==============================] - ETA: 0s - loss: 0.9046 - accuracy: 0.6626
# Epoch 27: val_accuracy improved from 0.64944 to 0.65922, saving model to model_weights.h5
# 359/359 [==============================] - 386s 1s/step - loss: 0.9046 - accuracy: 0.6626 - val_loss: 0.9439 - val_accuracy: 0.6592
# Epoch 28/50
# 359/359 [==============================] - ETA: 0s - loss: 0.8850 - accuracy: 0.6686
# Epoch 28: val_accuracy did not improve from 0.65922
# 359/359 [==============================] - 381s 1s/step - loss: 0.8850 - accuracy: 0.6686 - val_loss: 0.9637 - val_accuracy: 0.6313
# Epoch 29/50
# 359/359 [==============================] - ETA: 0s - loss: 0.8802 - accuracy: 0.6725
# Epoch 29: val_accuracy did not improve from 0.65922
# 359/359 [==============================] - 379s 1s/step - loss: 0.8802 - accuracy: 0.6725 - val_loss: 1.0147 - val_accuracy: 0.6327
# Epoch 30/50
# 359/359 [==============================] - ETA: 0s - loss: 0.8692 - accuracy: 0.6754
# Epoch 30: val_accuracy did not improve from 0.65922
# 359/359 [==============================] - 384s 1s/step - loss: 0.8692 - accuracy: 0.6754 - val_loss: 1.0122 - val_accuracy: 0.6299
# Epoch 31/50
# 359/359 [==============================] - ETA: 0s - loss: 0.8594 - accuracy: 0.6802
# Epoch 31: val_accuracy did not improve from 0.65922
# 359/359 [==============================] - 385s 1s/step - loss: 0.8594 - accuracy: 0.6802 - val_loss: 0.9666 - val_accuracy: 0.6390
# Epoch 32/50
# 359/359 [==============================] - ETA: 0s - loss: 0.8537 - accuracy: 0.6832
# Epoch 32: val_accuracy did not improve from 0.65922
# 359/359 [==============================] - 379s 1s/step - loss: 0.8537 - accuracy: 0.6832 - val_loss: 0.9971 - val_accuracy: 0.6215
# Epoch 33/50
# 359/359 [==============================] - ETA: 0s - loss: 0.8446 - accuracy: 0.6827
# Epoch 33: val_accuracy did not improve from 0.65922
# 359/359 [==============================] - 391s 1s/step - loss: 0.8446 - accuracy: 0.6827 - val_loss: 0.9595 - val_accuracy: 0.6564
# Epoch 34/50
# 359/359 [==============================] - ETA: 0s - loss: 0.8317 - accuracy: 0.6898
# Epoch 34: val_accuracy improved from 0.65922 to 0.65992, saving model to model_weights.h5
# 359/359 [==============================] - 385s 1s/step - loss: 0.8317 - accuracy: 0.6898 - val_loss: 0.9708 - val_accuracy: 0.6599
# Epoch 35/50
# 359/359 [==============================] - ETA: 0s - loss: 0.8219 - accuracy: 0.6957
# Epoch 35: val_accuracy did not improve from 0.65992
# 359/359 [==============================] - 387s 1s/step - loss: 0.8219 - accuracy: 0.6957 - val_loss: 0.9596 - val_accuracy: 0.6550
# Epoch 36/50
# 359/359 [==============================] - ETA: 0s - loss: 0.8231 - accuracy: 0.6963
# Epoch 36: val_accuracy did not improve from 0.65992
# 359/359 [==============================] - 381s 1s/step - loss: 0.8231 - accuracy: 0.6963 - val_loss: 0.9521 - val_accuracy: 0.6515
# Epoch 37/50
# 359/359 [==============================] - ETA: 0s - loss: 0.8092 - accuracy: 0.6995
# Epoch 37: val_accuracy improved from 0.65992 to 0.66550, saving model to model_weights.h5
# 359/359 [==============================] - 382s 1s/step - loss: 0.8092 - accuracy: 0.6995 - val_loss: 0.9461 - val_accuracy: 0.6655
# Epoch 38/50
# 359/359 [==============================] - ETA: 0s - loss: 0.8040 - accuracy: 0.7005
# Epoch 38: val_accuracy did not improve from 0.66550
# 359/359 [==============================] - 380s 1s/step - loss: 0.8040 - accuracy: 0.7005 - val_loss: 0.9420 - val_accuracy: 0.6564
# Epoch 39/50
# 359/359 [==============================] - ETA: 0s - loss: 0.8003 - accuracy: 0.7060
# Epoch 39: val_accuracy did not improve from 0.66550
# 359/359 [==============================] - 387s 1s/step - loss: 0.8003 - accuracy: 0.7060 - val_loss: 0.9434 - val_accuracy: 0.6592
# Epoch 40/50
# 359/359 [==============================] - ETA: 0s - loss: 0.7851 - accuracy: 0.7064
# Epoch 40: val_accuracy did not improve from 0.66550
# 359/359 [==============================] - 391s 1s/step - loss: 0.7851 - accuracy: 0.7064 - val_loss: 0.9591 - val_accuracy: 0.6466
# Epoch 41/50
# 359/359 [==============================] - ETA: 0s - loss: 0.7804 - accuracy: 0.7113
# Epoch 41: val_accuracy did not improve from 0.66550
# 359/359 [==============================] - 380s 1s/step - loss: 0.7804 - accuracy: 0.7113 - val_loss: 0.9659 - val_accuracy: 0.6599
# Epoch 42/50
# 359/359 [==============================] - ETA: 0s - loss: 0.7707 - accuracy: 0.7157
# Epoch 42: val_accuracy did not improve from 0.66550
# 359/359 [==============================] - 386s 1s/step - loss: 0.7707 - accuracy: 0.7157 - val_loss: 0.9905 - val_accuracy: 0.6473
# Epoch 43/50
# 359/359 [==============================] - ETA: 0s - loss: 0.7732 - accuracy: 0.7102
# Epoch 43: val_accuracy improved from 0.66550 to 0.67109, saving model to model_weights.h5
# 359/359 [==============================] - 382s 1s/step - loss: 0.7732 - accuracy: 0.7102 - val_loss: 0.9439 - val_accuracy: 0.6711
# Epoch 44/50
# 359/359 [==============================] - ETA: 0s - loss: 0.7582 - accuracy: 0.7188
# Epoch 44: val_accuracy did not improve from 0.67109
# 359/359 [==============================] - 386s 1s/step - loss: 0.7582 - accuracy: 0.7188 - val_loss: 0.9532 - val_accuracy: 0.6585
# Epoch 45/50
# 359/359 [==============================] - ETA: 0s - loss: 0.7474 - accuracy: 0.7239
# Epoch 45: val_accuracy did not improve from 0.67109
# 359/359 [==============================] - 386s 1s/step - loss: 0.7474 - accuracy: 0.7239 - val_loss: 0.9377 - val_accuracy: 0.6697
# Epoch 46/50
# 359/359 [==============================] - ETA: 0s - loss: 0.7419 - accuracy: 0.7226
# Epoch 46: val_accuracy did not improve from 0.67109
# 359/359 [==============================] - 384s 1s/step - loss: 0.7419 - accuracy: 0.7226 - val_loss: 1.0122 - val_accuracy: 0.6466
# Epoch 47/50
# 359/359 [==============================] - ETA: 0s - loss: 0.7383 - accuracy: 0.7219
# Epoch 47: val_accuracy did not improve from 0.67109
# 359/359 [==============================] - 377s 1s/step - loss: 0.7383 - accuracy: 0.7219 - val_loss: 0.9880 - val_accuracy: 0.6383
# Epoch 48/50
# 359/359 [==============================] - ETA: 0s - loss: 0.7303 - accuracy: 0.7264
# Epoch 48: val_accuracy did not improve from 0.67109
# 359/359 [==============================] - 390s 1s/step - loss: 0.7303 - accuracy: 0.7264 - val_loss: 0.9646 - val_accuracy: 0.6599
# Epoch 49/50
# 359/359 [==============================] - ETA: 0s - loss: 0.7192 - accuracy: 0.7316
# Epoch 49: val_accuracy did not improve from 0.67109
# 359/359 [==============================] - 383s 1s/step - loss: 0.7192 - accuracy: 0.7316 - val_loss: 0.9320 - val_accuracy: 0.6655
# Epoch 50/50
# 359/359 [==============================] - ETA: 0s - loss: 0.7126 - accuracy: 0.7364
# Epoch 50: val_accuracy did not improve from 0.67109
# 359/359 [==============================] - 387s 1s/step - loss: 0.7126 - accuracy: 0.7364 - val_loss: 0.9681 - val_accuracy: 0.6697

# %% [markdown]
# ## Evaluation

# %% [markdown]
# ### Training and validation loss curves

# %%
# Plot the train and validation loss
train_loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(train_loss) + 1)
plt.plot(epochs, train_loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# ### Training and validation accuracy curves

# %%
# Plot the train and validation accuracy
train_acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
plt.plot(epochs, train_acc, 'bo', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# ### Confusion Matrix

# %%
import seaborn as sns 
from sklearn.metrics import confusion_matrix

# Get the true labels and predicted labels for the validation set
validation_labels = validation_generator.classes
validation_pred_probs = model.predict(validation_generator)
validation_pred_labels = np.argmax(validation_pred_probs, axis=1)

# Compute the confusion matrix
confusion_mtx = confusion_matrix(validation_labels, validation_pred_labels)
class_names = list(train_generator.class_indices.keys())
sns.set()
sns.heatmap(confusion_mtx, annot=True, fmt='d', cmap='YlGnBu', 
            xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 23/23 [==============================] - 5s 210ms/step
